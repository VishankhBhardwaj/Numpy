# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1,2,3,],[4,5,6]])
array2 = np.random.rand(3,3)
array3 = np.zeros([4,4])

# %%
np.save("array1.npy",array1)
np.save("array2.npy",array2)
np.save("array3.npy",array3)

# %%
loaded_array1=np.load('array1.npy')
print(loaded_array1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
try:
    logo = np.load('numpy-logo.npy')
    #Display
    plt.figure(figsize=(10,5))
    # The plt.Subplot(121) is incorrect here; if you want to use subplots, use plt.subplot
    # However, for a single image, you can simply proceed without it or use plt.subplot(1,2,1) if you plan to add more plots.
    # For now, just remove or comment out the incorrect line.
    # plt.subplot(121)  # Not needed for a single plot
    plt.imshow(logo)
    plt.title("Numpy logo")
    plt.grid(False)
    plt.show()
    dark_logo = 1-logo

    plt.imshow(dark_logo)
    plt.title("Dark Numpy logo")
    plt.grid(False)
except FileNotFoundError:
    print("numpy logo file not found")
